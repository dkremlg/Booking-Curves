# %%
library(partykit)

Data=read.csv('R_Training_Pax.csv')
Data[Data[,'NumPax']<0,'NumPax']=0

class(eq.mob <- NumPax ~ 1 + Dprio | dday + dtime + Direction + month)  

curve.model <- glmtree(
  eq.mob, 
  data = Data,
  family = poisson, 
  alpha = 0.01,
  bonferroni = TRUE,
  verbose = TRUE,
  prune = "BIC",
  minsize = 10,
  breakties = TRUE,
  restart = TRUE,
  maxdepth=5)
# Out:
# Warning message:
# "package 'partykit' was built under R version 3.5.3"Loading required package: grid
# Loading required package: libcoin
# Warning message:
# "package 'libcoin' was built under R version 3.5.3"Loading required package: mvtnorm
# Warning message:
# "package 'mvtnorm' was built under R version 3.5.2"
# [1] "formula"
# -- Node 1 ---------------------------------
# Number of observations: 646780
#
# Parameter instability tests:
#                    dday       dtime Direction         month
# statistic  7.620249e+02 2.07003e+02 6.9556721  5.209145e+02
# p.value   9.155664e-155 1.07601e-44 0.1178941 1.985525e-116
#
# Best splitting variable: dday
# Perform split? yes
# Selected split: Friday, Saturday, Sunday | Monday, Thursday, Tuesday, Wednesday
#
# -- Node 2 ---------------------------------
# Number of observations: 210240
#
# Parameter instability tests:
#                   dday        dtime    Direction        month
# statistic 1.035437e+02 1.972616e+02 5.340814e+01 1.688868e+02
# p.value   6.921926e-21 1.777002e-42 1.010718e-11 5.041287e-36
#
# Best splitting variable: dtime
# Perform split? yes
# Selected split: <= 465 | > 465
#
# -- Node 3 ---------------------------------
# Number of observations: 36865
#
# Parameter instability tests:
#                   dday        dtime Direction        month
# statistic 15.255563576 6.211945e+01         0 3.254004e+01
# p.value    0.001460218 4.210729e-12        NA 1.152637e-05
#
# Best splitting variable: dtime
# Perform split? yes
# Selected split: <= 405 | > 405
#
# -- Node 4 ---------------------------------
# Number of observations: 22995
#
# Parameter instability tests:
#                   dday dtime Direction        month
# statistic 11.582182487     0         0 21.049799881
# p.value    0.006099963    NA        NA  0.001868311
#
# Best splitting variable: month
# Perform split? yes
# Selected split: <= 5 | > 5
#
# -- Node 5 ---------------------------------
# Number of observations: 6935
# Maximum depth reached, stop splitting (maxdepth = 5)
#
# -- Node 6 ---------------------------------
# Number of observations: 16060
# Maximum depth reached, stop splitting (maxdepth = 5)
#
# -- Node 7 ---------------------------------
# Number of observations: 13870
#
# Parameter instability tests:
#                dday dtime Direction     month
# statistic 3.9967269     0         0 8.4022435
# p.value   0.2527382    NA        NA 0.3790254
#
# Best splitting variable: dday
# Perform split? no
#
# -- Node 8 ---------------------------------
# Number of observations: 173375
#
# Parameter instability tests:
#                   dday        dtime    Direction        month
# statistic 5.617366e+01 1.185497e+02 2.185435e+01 1.442774e+02
# p.value   7.375648e-11 1.282969e-24 7.185342e-05 1.937472e-30
#
# Best splitting variable: month
# Perform split? yes
# Selected split: <= 4 | > 4
#
# -- Node 9 ---------------------------------
# Number of observations: 45625
#
# Parameter instability tests:
#                   dday        dtime Direction        month
# statistic 19.204814800 3.254401e+01 1.7913547 4.672769e+01
# p.value    0.002865444 1.533878e-05 0.8774494 1.352372e-08
#
# Best splitting variable: month
# Perform split? yes
# Selected split: <= 1 | > 1
#
# -- Node 10 --------------------------------
# Number of observations: 14235
# Maximum depth reached, stop splitting (maxdepth = 5)
#
# -- Node 11 --------------------------------
# Number of observations: 31390
# Maximum depth reached, stop splitting (maxdepth = 5)
#
# -- Node 12 --------------------------------
# Number of observations: 127750
#
# Parameter instability tests:
#                  dday        dtime    Direction        month
# statistic 2.63049e+01 9.708895e+01 2.198866e+01 5.391557e+01
# p.value   1.09864e-04 8.774043e-20 6.718679e-05 3.614524e-10
#
# Best splitting variable: dtime
# Perform split? yes
# Selected split: <= 960 | > 960
#
# -- Node 13 --------------------------------
# Number of observations: 76650
# Maximum depth reached, stop splitting (maxdepth = 5)
#
# -- Node 14 --------------------------------
# Number of observations: 51100
# Maximum depth reached, stop splitting (maxdepth = 5)
#
# -- Node 15 --------------------------------
# Number of observations: 436540
#
# Parameter instability tests:
#                   dday        dtime    Direction        month
# statistic 1.369647e+02 2.215126e+02 3.491612e+01 3.329559e+02
# p.value   1.751327e-26 5.326247e-48 1.047422e-07 1.948576e-73
#
# Best splitting variable: month
# Perform split? yes
# Selected split: <= 3 | > 3
#
# -- Node 16 --------------------------------
# Number of observations: 80665
#
# Parameter instability tests:
#                   dday        dtime Direction        month
# statistic 2.644111e+01 6.866600e+01 2.4644135 5.196621e+01
# p.value   7.368711e-04 1.986173e-13 0.7482347 9.680363e-10
#
# Best splitting variable: dtime
# Perform split? yes
# Selected split: <= 465 | > 465
#
# -- Node 17 --------------------------------
# Number of observations: 10950
#
# Parameter instability tests:
#                dday dtime Direction     month
# statistic 8.3413190     0         0 7.8974661
# p.value   0.3824374    NA        NA 0.4437144
#
# Best splitting variable: dday
# Perform split? no
#
# -- Node 18 --------------------------------
# Number of observations: 69715
#
# Parameter instability tests:
#                   dday        dtime Direction        month
# statistic 3.412557e+01 5.393155e+01 6.4228802 5.163005e+01
# p.value   2.544807e-05 3.585485e-10 0.1517095 1.147056e-09
#
# Best splitting variable: dtime
# Perform split? yes
# Selected split: <= 580 | > 580
#
# -- Node 19 --------------------------------
# Number of observations: 11680
# Maximum depth reached, stop splitting (maxdepth = 5)
#
# -- Node 20 --------------------------------
# Number of observations: 58035
# Maximum depth reached, stop splitting (maxdepth = 5)
#
# -- Node 21 --------------------------------
# Number of observations: 355875
#
# Parameter instability tests:
#                   dday        dtime    Direction        month
# statistic 1.098962e+02 1.456588e+02 3.664763e+01 1.286434e+02
# p.value   8.572192e-21 9.421108e-31 4.406858e-08 6.715634e-27
#
# Best splitting variable: dtime
# Perform split? yes
# Selected split: <= 960 | > 960
#
# -- Node 22 --------------------------------
# Number of observations: 237980
#
# Parameter instability tests:
#                   dday        dtime    Direction        month
# statistic 8.392653e+01 1.532676e+02 7.848816e+01 9.167673e+01
# p.value   2.203152e-15 1.772566e-32 3.618870e-17 1.440225e-18
#
# Best splitting variable: dtime
# Perform split? yes
# Selected split: <= 580 | > 580
#
# -- Node 23 --------------------------------
# Number of observations: 117895
# Maximum depth reached, stop splitting (maxdepth = 5)
#
# -- Node 24 --------------------------------
# Number of observations: 120085
# Maximum depth reached, stop splitting (maxdepth = 5)
#
# -- Node 25 --------------------------------
# Number of observations: 117895
#
# Parameter instability tests:
#                   dday        dtime    Direction        month
# statistic 7.989992e+01 1.041843e+02 1.034329e+02 4.200066e+01
# p.value   1.498820e-14 2.224957e-21 1.386402e-22 1.438123e-07
#
# Best splitting variable: Direction
# Perform split? yes
# Selected split: I | O
#
# -- Node 26 --------------------------------
# Number of observations: 59130
# Maximum depth reached, stop splitting (maxdepth = 5)
#
# -- Node 27 --------------------------------
# Number of observations: 58765
# Maximum depth reached, stop splitting (maxdepth = 5)
#
# -- Post-pruning ---------------------------
# Warning message in file(file, ifelse(append, "a", "w")):
# "kann Datei 'R_Output_Training_Pax.csv' nicht öffnen: Permission denied"
# Error in file(file, ifelse(append, "a", "w")): kann Verbindung nicht öffnen
# Traceback:
#
# 1. write.csv(Data, "R_Output_Training_Pax.csv", row.names = FALSE)
# 2. eval.parent(Call)
# 3. eval(expr, p)
# 4. eval(expr, p)
# 5. write.table(Data, "R_Output_Training_Pax.csv", row.names = FALSE,
#  .     col.names = TRUE, sep = ",", dec = ".", qmethod = "double")
# 6. file(file, ifelse(append, "a", "w"))

# %%
forecast_bookings=as.numeric(predict(curve.model,newdata=Data,type='response'))
forecast_node=as.numeric(predict(curve.model,newdata=Data,type='node'))
Data=cbind(Data,forecast_bookings,forecast_node)
write.csv(Data,'R_Output_Training_Pax.csv',row.names=FALSE)

#######################################################

Forecast_Data=read.csv('R_Test_Pax.csv')
forecast_bookings=as.numeric(predict(curve.model,newdata=Forecast_Data,type='response'))
forecast_node=as.numeric(predict(curve.model,newdata=Forecast_Data,type='node'))
Forecast_Data=cbind(Forecast_Data,forecast_bookings,forecast_node)
write.csv(Forecast_Data,'R_Output_Test_Pax.csv',row.names=FALSE)
