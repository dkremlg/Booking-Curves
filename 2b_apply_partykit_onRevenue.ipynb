# %%
library(partykit)

Data=read.csv('R_Training_Revenue.csv')
Data[Data[,'Coupons.YQ.on.current.bookings']<0,'Coupons.YQ.on.current.bookings']=0
Data[,'Coupons.YQ.on.current.bookings']=round(Data[,'Coupons.YQ.on.current.bookings'])

class(eq.mob <- Coupons.YQ.on.current.bookings ~ 1 + Dprio | dday + dtime + Direction + month)  

curve.model <- glmtree(
  eq.mob, 
  data = Data,
  family = poisson, 
  alpha = 0.25,
  bonferroni = TRUE,
  verbose = TRUE,
  prune = "BIC",
  minsize = 10,
  breakties = TRUE,
  restart = TRUE,
  maxdepth=5)

forecast_revenue=as.numeric(predict(curve.model,newdata=Data,type='response'))
forecast_node=as.numeric(predict(curve.model,newdata=Data,type='node'))
Data=cbind(Data,forecast_revenue,forecast_node)
write.csv(Data,'R_Output_Training_Revenue.csv',row.names=FALSE)

#######################################################

Forecast_Data=read.csv('R_Test_Revenue.csv')
forecast_revenue=as.numeric(predict(curve.model,newdata=Forecast_Data,type='response'))
forecast_node=as.numeric(predict(curve.model,newdata=Forecast_Data,type='node'))
Forecast_Data=cbind(Forecast_Data,forecast_revenue,forecast_node)
write.csv(Forecast_Data,'R_Output_Test_Revenue.csv',row.names=FALSE)
# Out:
# Warning message:
# "package 'partykit' was built under R version 3.5.3"Loading required package: grid
# Loading required package: libcoin
# Warning message:
# "package 'libcoin' was built under R version 3.5.3"Loading required package: mvtnorm
# Warning message:
# "package 'mvtnorm' was built under R version 3.5.2"
# [1] "formula"
# -- Node 1 ---------------------------------
# Number of observations: 646780
#
# Parameter instability tests:
#                    dday        dtime    Direction         month
# statistic  1.424630e+03 3.703231e+02 4.515788e+01  5.798140e+02
# p.value   2.721908e-297 5.608996e-82 6.253910e-10 6.511542e-130
#
# Best splitting variable: dday
# Perform split? yes
# Selected split: Friday, Saturday, Sunday | Monday, Thursday, Tuesday, Wednesday
#
# -- Node 2 ---------------------------------
# Number of observations: 210240
#
# Parameter instability tests:
#                   dday        dtime    Direction        month
# statistic 3.410768e+02 3.463276e+02 3.394510e+02 1.848140e+02
# p.value   5.922978e-72 1.713542e-76 7.783978e-74 1.207656e-39
#
# Best splitting variable: dtime
# Perform split? yes
# Selected split: <= 825 | > 825
#
# -- Node 3 ---------------------------------
# Number of observations: 85410
#
# Parameter instability tests:
#                   dday        dtime    Direction        month
# statistic 7.258174e+01 1.121972e+02 7.816964e+01 6.703615e+01
# p.value   2.586652e-14 3.481237e-23 4.243633e-17 4.569592e-13
#
# Best splitting variable: dtime
# Perform split? yes
# Selected split: <= 465 | > 465
#
# -- Node 4 ---------------------------------
# Number of observations: 36865
#
# Parameter instability tests:
#                   dday        dtime Direction        month
# statistic 3.272728e+01 4.288578e+01         0 4.307157e+01
# p.value   2.346837e-07 6.936812e-08        NA 6.322486e-08
#
# Best splitting variable: month
# Perform split? yes
# Selected split: <= 3 | > 3
#
# -- Node 5 ---------------------------------
# Number of observations: 7300
# Maximum depth reached, stop splitting (maxdepth = 5)
#
# -- Node 6 ---------------------------------
# Number of observations: 29565
# Maximum depth reached, stop splitting (maxdepth = 5)
#
# -- Node 7 ---------------------------------
# Number of observations: 48545
#
# Parameter instability tests:
#                   dday      dtime   Direction        month
# statistic 4.191439e+01 10.8058241 10.20135555 4.344997e+01
# p.value   6.950942e-08  0.2966102  0.02414865 6.978628e-08
#
# Best splitting variable: dday
# Perform split? yes
# Selected split: Friday | Saturday, Sunday
#
# -- Node 8 ---------------------------------
# Number of observations: 25185
# Maximum depth reached, stop splitting (maxdepth = 5)
#
# -- Node 9 ---------------------------------
# Number of observations: 23360
# Maximum depth reached, stop splitting (maxdepth = 5)
#
# -- Node 10 --------------------------------
# Number of observations: 124830
#
# Parameter instability tests:
#                   dday        dtime    Direction        month
# statistic 1.421679e+02 2.810167e+02 3.137266e+02 1.113062e+02
# p.value   5.378840e-31 1.422549e-61 3.000456e-68 5.529282e-23
#
# Best splitting variable: Direction
# Perform split? yes
# Selected split: I | O
#
# -- Node 11 --------------------------------
# Number of observations: 68255
#
# Parameter instability tests:
#                   dday        dtime Direction        month
# statistic 1.752860e+02 1.674255e+02         0 7.143518e+01
# p.value   2.595708e-38 8.122081e-36        NA 3.609590e-14
#
# Best splitting variable: dday
# Perform split? yes
# Selected split: Friday | Sunday
#
# -- Node 12 --------------------------------
# Number of observations: 36500
# Maximum depth reached, stop splitting (maxdepth = 5)
#
# -- Node 13 --------------------------------
# Number of observations: 31755
# Maximum depth reached, stop splitting (maxdepth = 5)
#
# -- Node 14 --------------------------------
# Number of observations: 56575
#
# Parameter instability tests:
#                dday        dtime Direction        month
# statistic 3.7899886 7.885186e+01         0 5.447152e+01
# p.value   0.3865666 8.022559e-16        NA 2.046233e-10
#
# Best splitting variable: dtime
# Perform split? yes
# Selected split: <= 840 | > 840
#
# -- Node 15 --------------------------------
# Number of observations: 22630
# Maximum depth reached, stop splitting (maxdepth = 5)
#
# -- Node 16 --------------------------------
# Number of observations: 33945
# Maximum depth reached, stop splitting (maxdepth = 5)
#
# -- Node 17 --------------------------------
# Number of observations: 436540
#
# Parameter instability tests:
#                   dday         dtime    Direction        month
# statistic 3.177160e+02  1.320306e+03 7.497853e+01 4.074402e+02
# p.value   5.216325e-65 1.100937e-299 2.092563e-16 1.826417e-90
#
# Best splitting variable: dtime
# Perform split? yes
# Selected split: <= 465 | > 465
#
# -- Node 18 --------------------------------
# Number of observations: 70080
#
# Parameter instability tests:
#                   dday        dtime Direction        month
# statistic 1.422811e+02 20.683606304         0 8.226314e+01
# p.value   9.921639e-28  0.003317824        NA 1.386892e-16
#
# Best splitting variable: dday
# Perform split? yes
# Selected split: Monday | Thursday, Tuesday, Wednesday
#
# -- Node 19 --------------------------------
# Number of observations: 16060
#
# Parameter instability tests:
#           dday     dtime Direction        month
# statistic    0 3.5502234         0 2.386303e+01
# p.value     NA 0.9817959        NA 5.000726e-04
#
# Best splitting variable: month
# Perform split? yes
# Selected split: <= 11 | > 11
#
# -- Node 20 --------------------------------
# Number of observations: 14235
# Maximum depth reached, stop splitting (maxdepth = 5)
#
# -- Node 21 --------------------------------
# Number of observations: 1825
# Maximum depth reached, stop splitting (maxdepth = 5)
#
# -- Node 22 --------------------------------
# Number of observations: 54020
#
# Parameter instability tests:
#                   dday        dtime Direction        month
# statistic 3.159921e+01 20.543964532         0 6.570641e+01
# p.value   6.930088e-06  0.003539128        NA 6.759527e-13
#
# Best splitting variable: month
# Perform split? yes
# Selected split: <= 4 | > 4
#
# -- Node 23 --------------------------------
# Number of observations: 16060
# Maximum depth reached, stop splitting (maxdepth = 5)
#
# -- Node 24 --------------------------------
# Number of observations: 37960
# Maximum depth reached, stop splitting (maxdepth = 5)
#
# -- Node 25 --------------------------------
# Number of observations: 366460
#
# Parameter instability tests:
#                    dday        dtime    Direction        month
# statistic  5.869773e+02 3.228195e+02 8.591531e+01 3.236737e+02
# p.value   6.007190e-123 4.034549e-71 8.826489e-19 2.574153e-71
#
# Best splitting variable: dday
# Perform split? yes
# Selected split: Monday, Tuesday | Thursday, Wednesday
#
# -- Node 26 --------------------------------
# Number of observations: 180675
#
# Parameter instability tests:
#                   dday        dtime    Direction        month
# statistic 8.203522e+01 7.351349e+01 2.871118e+01 1.636195e+02
# p.value   6.142416e-18 1.658592e-14 2.330813e-06 7.924468e-35
#
# Best splitting variable: month
# Perform split? yes
# Selected split: <= 3 | > 3
#
# -- Node 27 --------------------------------
# Number of observations: 32850
# Maximum depth reached, stop splitting (maxdepth = 5)
#
# -- Node 28 --------------------------------
# Number of observations: 147825
# Maximum depth reached, stop splitting (maxdepth = 5)
#
# -- Node 29 --------------------------------
# Number of observations: 185785
#
# Parameter instability tests:
#                   dday        dtime    Direction        month
# statistic 1.412365e+02 4.319097e+02 8.512775e+01 2.027879e+02
# p.value   8.569151e-31 4.621742e-96 1.308592e-18 9.809993e-44
#
# Best splitting variable: dtime
# Perform split? yes
# Selected split: <= 840 | > 840
#
# -- Node 30 --------------------------------
# Number of observations: 73730
# Maximum depth reached, stop splitting (maxdepth = 5)
#
# -- Node 31 --------------------------------
# Number of observations: 112055
# Maximum depth reached, stop splitting (maxdepth = 5)
#
# -- Post-pruning ---------------------------
