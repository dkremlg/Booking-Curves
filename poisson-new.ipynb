# %%
library(partykit)

# %%
Data=read.csv('R_Input.csv')

# %%
Data['dprio2']=Data['dprio']^2
Data['dprio3']=Data['dprio']^3

# %%
Data[Data[,'pax_total']<0,'pax_total']=0

# %%
class(eq.mob <- pax_total ~ 1 + dprio + dprio2 + dprio3 | weekday+direction+whichholiday_left_LUX+whichholiday_right_LUX+holiday_from_left_LUX+holiday_from_right_LUX+holiday_to_left_LUX+holiday_to_right_LUX)  

curve.model <- glmtree(
  eq.mob, 
  data = Data,
  family = poisson, 
  alpha = 0.01,
  bonferroni = TRUE,
  verbose = TRUE,
  prune = "BIC",
  minsize = 10,
  breakties = TRUE,
  restart = TRUE,
  maxdepth=10)
# Out:
# [1] "formula"
# -- Node 1 ---------------------------------
# Number of observations: 160308
#
# Parameter instability tests:
#                weekday    direction whichholiday_left_LUX
# statistic 4.660097e+02 3.600868e+01          6.632119e+02
# p.value   1.096245e-94 2.305453e-06         1.062220e-126
#           whichholiday_right_LUX holiday_from_left_LUX holiday_from_right_LUX
# statistic           7.646524e+02          2.049645e+02           2.019383e+02
# p.value            3.575954e-148          1.314205e-43           6.856832e-43
#           holiday_to_left_LUX holiday_to_right_LUX
# statistic        2.013221e+02         2.062240e+02
# p.value          9.597680e-43         6.606689e-44
#
# Best splitting variable: whichholiday_right_LUX
# Perform split? yes
# Selected split: vacances de Carnaval, Vacances de Noeel, Vacances de Pentecete, Vacances de Peques | La Toussaint, Vacances dete
#
# -- Node 2 ---------------------------------
# Number of observations: 85278
#
# Parameter instability tests:
#                weekday    direction whichholiday_left_LUX
# statistic 2.292317e+02 3.459109e+01          2.665858e+02
# p.value   3.443998e-44 4.508954e-06          1.618772e-46
#           whichholiday_right_LUX holiday_from_left_LUX holiday_from_right_LUX
# statistic           2.584017e+02          1.471194e+02           1.474978e+02
# p.value             1.932053e-47          5.888466e-30           4.799983e-30
#           holiday_to_left_LUX holiday_to_right_LUX
# statistic        1.475231e+02         1.561311e+02
# p.value          4.734671e-30         4.504008e-32
#
# Best splitting variable: whichholiday_right_LUX
# Perform split? yes
# Selected split: Vacances de Noeel, Vacances de Pentecete | vacances de Carnaval, Vacances de Peques
#
# -- Node 3 ---------------------------------
# Number of observations: 41358
#
# Parameter instability tests:
#                weekday   direction whichholiday_left_LUX whichholiday_right_LUX
# statistic 1.577057e+02 17.85195303          1.079992e+02           3.981227e+01
# p.value   3.860650e-29  0.01050404          1.189760e-16           3.786519e-07
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic          6.108674e+01           4.880201e+01        5.431614e+01
# p.value            3.609442e-10           1.773738e-07        1.120359e-08
#           holiday_to_right_LUX
# statistic         4.821704e+01
# p.value           2.372374e-07
#
# Best splitting variable: weekday
# Perform split? yes
# Warning message:
# "glm.fit: algorithm did not converge"
# Selected split: Sunday, Thursday | Wednesday
#
# -- Node 4 ---------------------------------
# Number of observations: 40260
#
# Parameter instability tests:
#                weekday  direction whichholiday_left_LUX whichholiday_right_LUX
# statistic 7.760853e+01 15.8871828          9.847928e+01           3.030857e+01
# p.value   4.472402e-15  0.0251144          8.839459e-15           3.388087e-05
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic          6.553838e+01           5.318486e+01        4.946529e+01
# p.value            3.690901e-11           1.980194e-08        1.274850e-07
#           holiday_to_right_LUX
# statistic         4.919363e+01
# p.value           1.459608e-07
#
# Best splitting variable: weekday
# Perform split? yes
# Selected split: Sunday | Thursday
#
# -- Node 5 ---------------------------------
# Number of observations: 26352
#
# Parameter instability tests:
#           weekday  direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0 11.7016897          7.231802e+01             11.0998558
# p.value        NA  0.1300937          8.239306e-10              0.1651971
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic          5.164561e+01           4.655509e+01        4.491035e+01
# p.value            3.751727e-08           4.729905e-07        1.064436e-06
#           holiday_to_right_LUX
# statistic         4.540751e+01
# p.value           8.333481e-07
#
# Best splitting variable: whichholiday_left_LUX
# Perform split? yes
# Selected split: La Toussaint | Vacances de Noeel, Vacances de Pentecete, Vacances de Peques
#
# -- Node 6 ---------------------------------
# Number of observations: 8052
#
# Parameter instability tests:
#           weekday   direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0 10.70381512                     0                      0
# p.value        NA  0.08761584                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0          16.9533050
# p.value                      NA                     NA           0.1334268
#           holiday_to_right_LUX
# statistic           14.7103668
# p.value              0.2826791
#
# Best splitting variable: direction
# Perform split? no
#
# -- Node 7 ---------------------------------
# Number of observations: 18300
#
# Parameter instability tests:
#           weekday direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0 7.3368807          3.216935e+01           2.375356e+01
# p.value        NA 0.5884584          6.079865e-04           6.264481e-04
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic          4.080769e+01           26.747759278        26.956395324
# p.value            7.898197e-06            0.005630437         0.005131973
#           holiday_to_right_LUX
# statistic         3.968451e+01
# p.value           1.359858e-05
#
# Best splitting variable: holiday_from_left_LUX
# Perform split? yes
# Selected split: <= 2 | > 2
#
# -- Node 8 ---------------------------------
# Number of observations: 13176
#
# Parameter instability tests:
#           weekday direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0 6.8353666              2.816599              1.3682745
# p.value        NA 0.6655725              1.000000              0.9999983
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic             7.3557961               9.873788           9.1084207
# p.value               0.9999502               0.985228           0.9957361
#           holiday_to_right_LUX
# statistic          20.06929706
# p.value             0.09282119
#
# Best splitting variable: holiday_to_right_LUX
# Perform split? no
#
# -- Node 9 ---------------------------------
# Number of observations: 5124
#
# Parameter instability tests:
#           weekday   direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0 12.04319847              6.024695               6.024695
# p.value        NA  0.08231232              0.666777               0.666777
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic             15.104315             10.7865188                   0
# p.value                0.380578              0.8900883                  NA
#           holiday_to_right_LUX
# statistic                    0
# p.value                     NA
#
# Best splitting variable: direction
# Perform split? no
#
# -- Node 10 --------------------------------
# Number of observations: 13908
#
# Parameter instability tests:
#           weekday direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0 7.0247181             8.7466107                      0
# p.value        NA 0.5799139             0.3435807                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic            14.9300976             11.2172114          18.7231446
# p.value               0.4583662              0.8985173           0.1336727
#           holiday_to_right_LUX
# statistic          21.57172920
# p.value             0.04397853
#
# Best splitting variable: holiday_to_right_LUX
# Perform split? no
#
# -- Node 11 --------------------------------
# Number of observations: 1098
# Warning message:
# "glm.fit: algorithm did not converge"
# Parameter instability tests:
#           weekday direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0         0          1.098000e+03                      0
# p.value        NA        NA         1.027217e-235                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic              9867.241               9864.255            9862.708
# p.value                   0.000                  0.000               0.000
#           holiday_to_right_LUX
# statistic             9864.077
# p.value                  0.000
#
# Best splitting variable: holiday_from_left_LUX
# Perform split? yes
# Warning message:
# "glm.fit: algorithm did not converge"Warning message:
# "glm.fit: algorithm did not converge"
# Selected split: <= 0 | > 0
#
# -- Node 12 --------------------------------
# Number of observations: 732
# Warning message:
# "glm.fit: algorithm did not converge"
# Parameter instability tests:
#           weekday direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0         0                     0                      0
# p.value        NA        NA                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0            6511.177
# p.value                      NA                     NA               0.000
#           holiday_to_right_LUX
# statistic             6509.355
# p.value                  0.000
#
# Best splitting variable: holiday_to_left_LUX
# Perform split? yes
# Warning message:
# "glm.fit: algorithm did not converge"Warning message:
# "glm.fit: algorithm did not converge"
# Selected split: <= 24 | > 24
#
# -- Node 13 --------------------------------
# Number of observations: 366
# Warning message:
# "glm.fit: algorithm did not converge"
# Parameter instability tests:
#           weekday direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0         0                     0                      0
# p.value        NA        NA                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0                   0
# p.value                      NA                     NA                  NA
#           holiday_to_right_LUX
# statistic                    0
# p.value                     NA
#
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Perform split? no
#
# -- Node 14 --------------------------------
# Number of observations: 366
# Warning message:
# "glm.fit: algorithm did not converge"
# Parameter instability tests:
#           weekday direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0         0                     0                      0
# p.value        NA        NA                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0                   0
# p.value                      NA                     NA                  NA
#           holiday_to_right_LUX
# statistic                    0
# p.value                     NA
#
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Perform split? no
#
# -- Node 15 --------------------------------
# Number of observations: 366
# Warning message:
# "glm.fit: algorithm did not converge"
# Parameter instability tests:
#           weekday direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0         0                     0                      0
# p.value        NA        NA                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0                   0
# p.value                      NA                     NA                  NA
#           holiday_to_right_LUX
# statistic                    0
# p.value                     NA
#
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Perform split? no
#
# -- Node 16 --------------------------------
# Number of observations: 43920
#
# Parameter instability tests:
#                weekday    direction whichholiday_left_LUX
# statistic 4.961937e+01 2.886926e+01          1.601659e+02
# p.value   3.468668e-09 6.648241e-05          1.181254e-29
#           whichholiday_right_LUX holiday_from_left_LUX holiday_from_right_LUX
# statistic             16.4568260          1.237194e+02           1.288840e+02
# p.value                0.0195398          1.739369e-24           1.087875e-25
#           holiday_to_left_LUX holiday_to_right_LUX
# statistic        1.248302e+02         1.253910e+02
# p.value          9.586740e-25         7.095854e-25
#
# Best splitting variable: whichholiday_left_LUX
# Perform split? yes
# Selected split: vacances de Carnaval, Vacances de Noeel | Vacances de Peques
#
# -- Node 17 --------------------------------
# Number of observations: 32940
#
# Parameter instability tests:
#                weekday    direction whichholiday_left_LUX
# statistic 4.999605e+01 2.512173e+01          3.140267e+01
# p.value   2.894189e-09 3.804191e-04          2.026930e-05
#           whichholiday_right_LUX holiday_from_left_LUX holiday_from_right_LUX
# statistic           22.061858424          6.658234e+01           6.461392e+01
# p.value              0.001558538          2.157509e-11           5.933785e-11
#           holiday_to_left_LUX holiday_to_right_LUX
# statistic        6.527622e+01         6.742702e+01
# p.value          4.223116e-11         1.396495e-11
#
# Best splitting variable: holiday_to_right_LUX
# Perform split? yes
# Selected split: <= 0 | > 0
#
# -- Node 18 --------------------------------
# Number of observations: 5124
#
# Parameter instability tests:
#               weekday direction whichholiday_left_LUX whichholiday_right_LUX
# statistic 13.94987789 4.8323404                     0                      0
# p.value    0.02949506 0.7666022                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic             6.5200253              6.7094831                   0
# p.value               0.9994958              0.9991717                  NA
#           holiday_to_right_LUX
# statistic                    0
# p.value                     NA
#
# Best splitting variable: weekday
# Perform split? no
#
# -- Node 19 --------------------------------
# Number of observations: 27816
#
# Parameter instability tests:
#                weekday    direction whichholiday_left_LUX
# statistic 3.622597e+01 2.670313e+01          2.250707e+01
# p.value   1.559945e-06 1.369428e-04          9.529383e-04
#           whichholiday_right_LUX holiday_from_left_LUX holiday_from_right_LUX
# statistic           2.250707e+01                     0                      0
# p.value             9.529383e-04                    NA                     NA
#           holiday_to_left_LUX holiday_to_right_LUX
# statistic        3.520729e+01         3.288927e+01
# p.value          9.896815e-05         2.937655e-04
#
# Best splitting variable: weekday
# Perform split? yes
# Selected split: Sunday | Thursday
#
# -- Node 20 --------------------------------
# Number of observations: 21960
#
# Parameter instability tests:
#           weekday   direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0 16.52666322          21.514402456           21.514402456
# p.value        NA  0.01188348           0.001251644            0.001251644
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0        4.470438e+01
# p.value                      NA                     NA        8.414349e-07
#           holiday_to_right_LUX
# statistic         3.939658e+01
# p.value           1.116047e-05
#
# Best splitting variable: holiday_to_left_LUX
# Perform split? yes
# Selected split: <= 27 | > 27
#
# -- Node 21 --------------------------------
# Number of observations: 13908
#
# Parameter instability tests:
#           weekday  direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0 11.5324037          3.537567e+01           3.537567e+01
# p.value        NA  0.1015505          1.944468e-06           1.944468e-06
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0           7.7890811
# p.value                      NA                     NA           0.9977506
#           holiday_to_right_LUX
# statistic            5.0621181
# p.value              0.9999999
#
# Best splitting variable: whichholiday_left_LUX
# Perform split? yes
# Selected split: vacances de Carnaval | Vacances de Noeel
#
# -- Node 22 --------------------------------
# Number of observations: 6588
#
# Parameter instability tests:
#           weekday direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0 7.5320762                     0                      0
# p.value        NA 0.2957511                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0           4.6415583
# p.value                      NA                     NA           0.9999932
#           holiday_to_right_LUX
# statistic            8.1898391
# p.value              0.9588716
#
# Best splitting variable: direction
# Perform split? no
#
# -- Node 23 --------------------------------
# Number of observations: 7320
#
# Parameter instability tests:
#           weekday direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0 9.6614478                     0                      0
# p.value        NA 0.1332052                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0           8.1723896
# p.value                      NA                     NA           0.9596611
#           holiday_to_right_LUX
# statistic             7.490747
# p.value               0.982630
#
# Best splitting variable: direction
# Perform split? no
#
# -- Node 24 --------------------------------
# Number of observations: 8052
#
# Parameter instability tests:
#           weekday direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0 7.9249829           15.83581541            15.83581541
# p.value        NA 0.3907919            0.01613276             0.01613276
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0          11.4519132
# p.value                      NA                     NA           0.8276592
#           holiday_to_right_LUX
# statistic            9.6027772
# p.value              0.9630587
#
# Best splitting variable: whichholiday_left_LUX
# Perform split? no
#
# -- Node 25 --------------------------------
# Number of observations: 5856
#
# Parameter instability tests:
#           weekday    direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0 2.321314e+01             3.1823956              3.1823956
# p.value        NA 5.739806e-04             0.9765185              0.9765185
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0        3.044756e+01
# p.value                      NA                     NA        7.568036e-04
#           holiday_to_right_LUX
# statistic         28.035797994
# p.value            0.002261822
#
# Best splitting variable: direction
# Perform split? yes
# Selected split: I | O
#
# -- Node 26 --------------------------------
# Number of observations: 2928
#
# Parameter instability tests:
#           weekday direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0         0             7.5725942              7.5725942
# p.value        NA        NA             0.3684801              0.3684801
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0           12.024388
# p.value                      NA                     NA            0.684699
#           holiday_to_right_LUX
# statistic           12.1051254
# p.value              0.6744656
#
# Best splitting variable: whichholiday_left_LUX
# Perform split? no
#
# -- Node 27 --------------------------------
# Number of observations: 2928
#
# Parameter instability tests:
#           weekday direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0         0             4.1078384              4.1078384
# p.value        NA        NA             0.8629959              0.8629959
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0        27.639589799
# p.value                      NA                     NA         0.002161342
#           holiday_to_right_LUX
# statistic         3.026289e+01
# p.value           6.588788e-04
#
# Best splitting variable: holiday_to_right_LUX
# Perform split? yes
# Selected split: <= 9 | > 9
#
# -- Node 28 --------------------------------
# Number of observations: 1464
#
# Parameter instability tests:
#           weekday direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0         0             7.8123786              7.8123786
# p.value        NA        NA             0.3400948              0.3400948
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0           8.4598438
# p.value                      NA                     NA           0.9792737
#           holiday_to_right_LUX
# statistic            4.7944588
# p.value              0.9999996
#
# Best splitting variable: whichholiday_left_LUX
# Perform split? no
#
# -- Node 29 --------------------------------
# Number of observations: 1464
#
# Parameter instability tests:
#           weekday direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0         0                     0                      0
# p.value        NA        NA                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0           9.1607271
# p.value                      NA                     NA           0.7833836
#           holiday_to_right_LUX
# statistic           10.8053604
# p.value              0.5837735
#
# Best splitting variable: holiday_to_right_LUX
# Perform split? no
#
# -- Node 30 --------------------------------
# Number of observations: 10980
#
# Parameter instability tests:
#                weekday direction whichholiday_left_LUX whichholiday_right_LUX
# statistic 26.995752645 8.9854638                     0                      0
# p.value    0.000079673 0.2241031                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic           19.69496310           28.555038007                   0
# p.value              0.06274635            0.001432552                  NA
#           holiday_to_right_LUX
# statistic                    0
# p.value                     NA
#
# Best splitting variable: weekday
# Perform split? yes
# Selected split: Sunday | Thursday
#
# -- Node 31 --------------------------------
# Number of observations: 6588
#
# Parameter instability tests:
#           weekday direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0 7.7079201                     0                      0
# p.value        NA 0.2779827                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic             15.921590           4.729916e+01                   0
# p.value                0.191035           1.402625e-07                  NA
#           holiday_to_right_LUX
# statistic                    0
# p.value                     NA
#
# Best splitting variable: holiday_from_right_LUX
# Perform split? yes
# Selected split: <= 8 | > 8
#
# -- Node 32 --------------------------------
# Number of observations: 3660
#
# Parameter instability tests:
#           weekday    direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0 15.996316691                     0                      0
# p.value        NA  0.009044922                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic            16.2841463              17.555179                   0
# p.value               0.1688274               0.107338                  NA
#           holiday_to_right_LUX
# statistic                    0
# p.value                     NA
#
# Best splitting variable: direction
# Perform split? yes
# Selected split: I | O
#
# -- Node 33 --------------------------------
# Number of observations: 1830
#
# Parameter instability tests:
#           weekday direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0         0                     0                      0
# p.value        NA        NA                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic            15.4012267             16.4674582                   0
# p.value               0.1577732              0.1086292                  NA
#           holiday_to_right_LUX
# statistic                    0
# p.value                     NA
#
# Best splitting variable: holiday_from_right_LUX
# Perform split? no
#
# -- Node 34 --------------------------------
# Number of observations: 1830
#
# Parameter instability tests:
#           weekday direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0         0                     0                      0
# p.value        NA        NA                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic           21.05799365           22.881039916                   0
# p.value              0.01838496            0.008605744                  NA
#           holiday_to_right_LUX
# statistic                    0
# p.value                     NA
#
# Best splitting variable: holiday_from_right_LUX
# Perform split? yes
# Selected split: <= 2 | > 2
#
# -- Node 35 --------------------------------
# Number of observations: 1098
#
# Parameter instability tests:
#           weekday direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0         0                     0                      0
# p.value        NA        NA                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0             11.3852510                   0
# p.value                      NA              0.3021071                  NA
#           holiday_to_right_LUX
# statistic                    0
# p.value                     NA
#
# Best splitting variable: holiday_from_right_LUX
# Perform split? no
#
# -- Node 36 --------------------------------
# Number of observations: 732
#
# Parameter instability tests:
#           weekday direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0         0                     0                      0
# p.value        NA        NA                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0                   0
# p.value                      NA                     NA                  NA
#           holiday_to_right_LUX
# statistic                    0
# p.value                     NA
#
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Perform split? no
#
# -- Node 37 --------------------------------
# Number of observations: 2928
#
# Parameter instability tests:
#           weekday   direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0 11.45375872                     0                      0
# p.value        NA  0.06430315                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic          2.993503e+01           26.866241893                   0
# p.value            5.740584e-04            0.002288715                  NA
#           holiday_to_right_LUX
# statistic                    0
# p.value                     NA
#
# Best splitting variable: holiday_from_left_LUX
# Perform split? yes
# Selected split: <= 2 | > 2
#
# -- Node 38 --------------------------------
# Number of observations: 2196
#
# Parameter instability tests:
#           weekday    direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0 17.967975134                     0                      0
# p.value        NA  0.002502453                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0           5.290229e+01                   0
# p.value                      NA           5.703556e-09                  NA
#           holiday_to_right_LUX
# statistic                    0
# p.value                     NA
#
# Best splitting variable: holiday_from_right_LUX
# Perform split? yes
# Selected split: <= 15 | > 15
#
# -- Node 39 --------------------------------
# Number of observations: 1464
#
# Parameter instability tests:
#           weekday   direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0 12.30254441                     0                      0
# p.value        NA  0.01523771                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0                   0
# p.value                      NA                     NA                  NA
#           holiday_to_right_LUX
# statistic                    0
# p.value                     NA
#
# Best splitting variable: direction
# Perform split? no
#
# -- Node 40 --------------------------------
# Number of observations: 732
#
# Parameter instability tests:
#           weekday    direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0 2.822852e+01                     0                      0
# p.value        NA 1.121095e-05                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0                   0
# p.value                      NA                     NA                  NA
#           holiday_to_right_LUX
# statistic                    0
# p.value                     NA
#
# Best splitting variable: direction
# Perform split? yes
# Selected split: I | O
#
# -- Node 41 --------------------------------
# Number of observations: 366
#
# Parameter instability tests:
#           weekday direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0         0                     0                      0
# p.value        NA        NA                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0                   0
# p.value                      NA                     NA                  NA
#           holiday_to_right_LUX
# statistic                    0
# p.value                     NA
#
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Perform split? no
#
# -- Node 42 --------------------------------
# Number of observations: 366
#
# Parameter instability tests:
#           weekday direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0         0                     0                      0
# p.value        NA        NA                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0                   0
# p.value                      NA                     NA                  NA
#           holiday_to_right_LUX
# statistic                    0
# p.value                     NA
#
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Perform split? no
#
# -- Node 43 --------------------------------
# Number of observations: 732
#
# Parameter instability tests:
#           weekday    direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0 14.499710871                     0                      0
# p.value        NA  0.005859683                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0                   0
# p.value                      NA                     NA                  NA
#           holiday_to_right_LUX
# statistic                    0
# p.value                     NA
#
# Best splitting variable: direction
# Perform split? yes
# Selected split: I | O
#
# -- Node 44 --------------------------------
# Number of observations: 366
#
# Parameter instability tests:
#           weekday direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0         0                     0                      0
# p.value        NA        NA                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0                   0
# p.value                      NA                     NA                  NA
#           holiday_to_right_LUX
# statistic                    0
# p.value                     NA
#
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Perform split? no
#
# -- Node 45 --------------------------------
# Number of observations: 366
#
# Parameter instability tests:
#           weekday direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0         0                     0                      0
# p.value        NA        NA                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0                   0
# p.value                      NA                     NA                  NA
#           holiday_to_right_LUX
# statistic                    0
# p.value                     NA
#
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Perform split? no
#
# -- Node 46 --------------------------------
# Number of observations: 4392
#
# Parameter instability tests:
#           weekday direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0 3.1468903                     0                      0
# p.value        NA 0.8985129                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic             4.5348921             14.5634943                   0
# p.value               0.9999962              0.2956301                  NA
#           holiday_to_right_LUX
# statistic                    0
# p.value                     NA
#
# Best splitting variable: holiday_from_right_LUX
# Perform split? no
#
# -- Node 47 --------------------------------
# Number of observations: 75030
#
# Parameter instability tests:
#                weekday   direction whichholiday_left_LUX whichholiday_right_LUX
# statistic 2.099769e+02 14.62262322          2.021172e+02           1.476356e+02
# p.value   4.026536e-40  0.04355828          1.829865e-38           5.229276e-30
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic          1.223262e+02           1.314667e+02        1.257358e+02
# p.value            3.670570e-24           2.714904e-26        5.897274e-25
#           holiday_to_right_LUX
# statistic         1.861057e+02
# p.value           3.842735e-39
#
# Best splitting variable: weekday
# Perform split? yes
# Warning message:
# "glm.fit: algorithm did not converge"
# Selected split: Sunday, Thursday | Wednesday
#
# -- Node 48 --------------------------------
# Number of observations: 73200
#
# Parameter instability tests:
#                weekday  direction whichholiday_left_LUX whichholiday_right_LUX
# statistic 6.377860e+01 10.9001213          1.857115e+02           1.489827e+02
# p.value   3.722189e-12  0.2013298          5.196710e-35           2.690345e-30
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic          9.440404e+01           1.050160e+02        9.273550e+01
# p.value            1.052476e-17           3.791683e-20        2.540599e-17
#           holiday_to_right_LUX
# statistic         1.309548e+02
# p.value           3.575141e-26
#
# Best splitting variable: whichholiday_left_LUX
# Perform split? yes
# Selected split: Vacances de Pentecete | La Toussaint, Vacances dete
#
# -- Node 49 --------------------------------
# Number of observations: 24156
#
# Parameter instability tests:
#                weekday   direction whichholiday_left_LUX whichholiday_right_LUX
# statistic 4.159658e+01 14.02106487                     0                      0
# p.value   8.089086e-08  0.02860054                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0        4.560291e+01
# p.value                      NA                     NA        4.324984e-07
#           holiday_to_right_LUX
# statistic         5.064790e+01
# p.value           3.532313e-08
#
# Best splitting variable: holiday_to_right_LUX
# Perform split? yes
# Selected split: <= 16 | > 16
#
# -- Node 50 --------------------------------
# Number of observations: 10980
#
# Parameter instability tests:
#               weekday  direction whichholiday_left_LUX whichholiday_right_LUX
# statistic 13.28859293 10.8997233                     0                      0
# p.value    0.03920397  0.1063336                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0          10.4013393
# p.value                      NA                     NA           0.8666434
#           holiday_to_right_LUX
# statistic           14.9203496
# p.value              0.3365293
#
# Best splitting variable: weekday
# Perform split? no
#
# -- Node 51 --------------------------------
# Number of observations: 13176
#
# Parameter instability tests:
#                weekday direction whichholiday_left_LUX whichholiday_right_LUX
# statistic 3.908544e+01 7.3844108                     0                      0
# p.value   2.675602e-07 0.3918527                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0        26.701207138
# p.value                      NA                     NA         0.003284134
#           holiday_to_right_LUX
# statistic          19.08165772
# p.value             0.07957151
#
# Best splitting variable: weekday
# Perform split? yes
# Selected split: Sunday | Thursday
#
# -- Node 52 --------------------------------
# Number of observations: 6588
#
# Parameter instability tests:
#           weekday direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0 1.5514926                     0                      0
# p.value        NA 0.9939199                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0          11.5875094
# p.value                      NA                     NA           0.6347279
#           holiday_to_right_LUX
# statistic            5.6152473
# p.value              0.9996534
#
# Best splitting variable: holiday_to_left_LUX
# Perform split? no
#
# -- Node 53 --------------------------------
# Number of observations: 6588
#
# Parameter instability tests:
#           weekday direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0  7.233518                     0                      0
# p.value        NA  0.327895                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0          13.5031156
# p.value                      NA                     NA           0.4021127
#           holiday_to_right_LUX
# statistic           10.9259560
# p.value              0.7174037
#
# Best splitting variable: direction
# Perform split? no
#
# -- Node 54 --------------------------------
# Number of observations: 49044
#
# Parameter instability tests:
#                weekday    direction whichholiday_left_LUX
# statistic 8.506562e+01 18.849828917          1.148625e+02
# p.value   1.175282e-16  0.006729366          5.341560e-23
#           whichholiday_right_LUX holiday_from_left_LUX holiday_from_right_LUX
# statistic           8.273183e+01          1.773768e+02           1.767819e+02
# p.value             3.673829e-16          4.439536e-37           6.134825e-37
#           holiday_to_left_LUX holiday_to_right_LUX
# statistic        1.763615e+02         2.010490e+02
# p.value          7.709892e-37         1.114173e-42
#
# Best splitting variable: holiday_to_right_LUX
# Perform split? yes
# Selected split: <= 0 | > 0
#
# -- Node 55 --------------------------------
# Number of observations: 32208
#
# Parameter instability tests:
#                weekday    direction whichholiday_left_LUX
# statistic 3.231655e+01 18.409966856          1.198078e+02
# p.value   9.889516e-06  0.006140111          3.522645e-24
#           whichholiday_right_LUX holiday_from_left_LUX holiday_from_right_LUX
# statistic           1.198078e+02          1.136330e+02           8.368000e+01
# p.value             3.522645e-24          2.881222e-22           2.233957e-15
#           holiday_to_left_LUX holiday_to_right_LUX
# statistic                   0                    0
# p.value                    NA                   NA
#
# Best splitting variable: whichholiday_left_LUX
# Perform split? yes
# Selected split: La Toussaint | Vacances dete
#
# -- Node 56 --------------------------------
# Number of observations: 4392
#
# Parameter instability tests:
#                weekday    direction whichholiday_left_LUX
# statistic 1.104354e+02 2.330546e+01                     0
# p.value   2.350611e-22 4.400761e-04                    NA
#           whichholiday_right_LUX holiday_from_left_LUX holiday_from_right_LUX
# statistic                      0          7.674980e+01           7.712467e+01
# p.value                       NA          5.570381e-14           4.582164e-14
#           holiday_to_left_LUX holiday_to_right_LUX
# statistic                   0                    0
# p.value                    NA                   NA
#
# Best splitting variable: weekday
# Perform split? yes
# Selected split: Sunday | Thursday
#
# -- Node 57 --------------------------------
# Number of observations: 2928
#
# Parameter instability tests:
#           weekday   direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0 15.25752575                     0                      0
# p.value        NA  0.01253478                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic           20.00326277           25.963500490                   0
# p.value              0.04197268            0.003408082                  NA
#           holiday_to_right_LUX
# statistic                    0
# p.value                     NA
#
# Best splitting variable: holiday_from_right_LUX
# Perform split? yes
# Selected split: <= 1 | > 1
#
# -- Node 58 --------------------------------
# Number of observations: 1464
#
# Parameter instability tests:
#           weekday    direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0 6.772417e+01                     0                      0
# p.value        NA 6.858633e-14                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0                   0
# p.value                      NA                     NA                  NA
#           holiday_to_right_LUX
# statistic                    0
# p.value                     NA
#
# Best splitting variable: direction
# Perform split? yes
# Selected split: I | O
#
# -- Node 59 --------------------------------
# Number of observations: 732
#
# Parameter instability tests:
#           weekday direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0         0                     0                      0
# p.value        NA        NA                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0                   0
# p.value                      NA                     NA                  NA
#           holiday_to_right_LUX
# statistic                    0
# p.value                     NA
#
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Perform split? no
#
# -- Node 60 --------------------------------
# Number of observations: 732
#
# Parameter instability tests:
#           weekday direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0         0                     0                      0
# p.value        NA        NA                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0                   0
# p.value                      NA                     NA                  NA
#           holiday_to_right_LUX
# statistic                    0
# p.value                     NA
#
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Perform split? no
#
# -- Node 61 --------------------------------
# Number of observations: 1464
#
# Parameter instability tests:
#           weekday    direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0 3.105367e+01                     0                      0
# p.value        NA 2.985176e-06                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0                   0
# p.value                      NA                     NA                  NA
#           holiday_to_right_LUX
# statistic                    0
# p.value                     NA
#
# Best splitting variable: direction
# Perform split? yes
# Selected split: I | O
#
# -- Node 62 --------------------------------
# Number of observations: 732
#
# Parameter instability tests:
#           weekday direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0         0                     0                      0
# p.value        NA        NA                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0                   0
# p.value                      NA                     NA                  NA
#           holiday_to_right_LUX
# statistic                    0
# p.value                     NA
#
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# ...
# statistic                     0                      0         25.37396307
# p.value                      NA                     NA          0.00587938
#           holiday_to_right_LUX
# statistic         3.331020e+01
# p.value           1.608801e-04
#
# Best splitting variable: weekday
# Perform split? yes
# Selected split: Sunday | Thursday
#
# -- Node 72 --------------------------------
# Number of observations: 2928
#
# Parameter instability tests:
#           weekday direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0 4.6084347                     0                      0
# p.value        NA 0.6990792                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0          11.3339006
# p.value                      NA                     NA           0.6667252
#           holiday_to_right_LUX
# statistic           10.7559389
# p.value              0.7378911
#
# Best splitting variable: holiday_to_left_LUX
# Perform split? no
#
# -- Node 73 --------------------------------
# Number of observations: 2928
#
# Parameter instability tests:
#           weekday direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0 6.3480275                     0                      0
# p.value        NA 0.4377108                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0          11.7297556
# p.value                      NA                     NA           0.6166109
#           holiday_to_right_LUX
# statistic           15.3429804
# p.value              0.2313497
#
# Best splitting variable: holiday_to_right_LUX
# Perform split? no
#
# -- Node 74 --------------------------------
# Number of observations: 10980
#
# Parameter instability tests:
#                weekday   direction whichholiday_left_LUX whichholiday_right_LUX
# statistic 5.507204e+01 14.19831543                     0                      0
# p.value   1.255199e-10  0.02648594                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0           6.7983960
# p.value                      NA                     NA           0.9989715
#           holiday_to_right_LUX
# statistic            6.5818854
# p.value              0.9994069
#
# Best splitting variable: weekday
# Perform split? yes
# Selected split: Sunday | Thursday
#
# -- Node 75 --------------------------------
# Number of observations: 5124
#
# Parameter instability tests:
#           weekday direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0  1.483680                     0                      0
# p.value        NA  0.995046                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0          19.1528260
# p.value                      NA                     NA           0.0586296
#           holiday_to_right_LUX
# statistic          20.35389248
# p.value             0.03647871
#
# Best splitting variable: holiday_to_right_LUX
# Perform split? no
#
# -- Node 76 --------------------------------
# Number of observations: 5856
#
# Parameter instability tests:
#           weekday    direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0 20.605890994                     0                      0
# p.value        NA  0.001137105                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0          15.1487212
# p.value                      NA                     NA           0.2462991
#           holiday_to_right_LUX
# statistic           13.0517875
# p.value              0.4532814
#
# Best splitting variable: direction
# Perform split? yes
# Selected split: I | O
#
# -- Node 77 --------------------------------
# Number of observations: 2928
#
# Parameter instability tests:
#           weekday direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0         0                     0                      0
# p.value        NA        NA                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0          10.8980248
# p.value                      NA                     NA           0.5727699
#           holiday_to_right_LUX
# statistic           10.7687559
# p.value              0.5888399
#
# Best splitting variable: holiday_to_left_LUX
# Perform split? no
#
# -- Node 78 --------------------------------
# Number of observations: 2928
#
# Parameter instability tests:
#           weekday direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0         0                     0                      0
# p.value        NA        NA                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0        2.948005e+01
# p.value                      NA                     NA        4.708829e-04
#           holiday_to_right_LUX
# statistic         3.659286e+01
# p.value           1.709787e-05
#
# Best splitting variable: holiday_to_right_LUX
# Perform split? yes
# Selected split: <= 30 | > 30
#
# -- Node 79 --------------------------------
# Number of observations: 2196
#
# Parameter instability tests:
#           weekday direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0         0                     0                      0
# p.value        NA        NA                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0        3.171796e+01
# p.value                      NA                     NA        1.685789e-04
#           holiday_to_right_LUX
# statistic          18.70545570
# p.value             0.04699393
#
# Best splitting variable: holiday_to_left_LUX
# Perform split? yes
# Selected split: <= 21 | > 21
#
# -- Node 80 --------------------------------
# Number of observations: 1464
# Maximum depth reached, stop splitting (maxdepth = 10)
#
# -- Node 81 --------------------------------
# Number of observations: 732
# Maximum depth reached, stop splitting (maxdepth = 10)
#
# -- Node 82 --------------------------------
# Number of observations: 732
#
# Parameter instability tests:
#           weekday direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0         0                     0                      0
# p.value        NA        NA                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0           9.8956250
# p.value                      NA                     NA           0.4485013
#           holiday_to_right_LUX
# statistic                    0
# p.value                     NA
#
# Best splitting variable: holiday_to_left_LUX
# Perform split? no
#
# -- Node 83 --------------------------------
# Number of observations: 1830
# Warning message:
# "glm.fit: algorithm did not converge"
# Parameter instability tests:
#           weekday direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0         0                     0                      0
# p.value        NA        NA                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0            16471.24
# p.value                      NA                     NA                0.00
#           holiday_to_right_LUX
# statistic             16471.36
# p.value                   0.00
#
# Best splitting variable: holiday_to_right_LUX
# Perform split? yes
# Warning message:
# "glm.fit: algorithm did not converge"Warning message:
# "glm.fit: algorithm did not converge"Warning message:
# "glm.fit: algorithm did not converge"Warning message:
# "glm.fit: algorithm did not converge"Warning message:
# "glm.fit: algorithm did not converge"Warning message:
# "glm.fit: algorithm did not converge"Warning message:
# "glm.fit: algorithm did not converge"Warning message:
# "glm.fit: algorithm did not converge"
# Selected split: <= 17 | > 17
#
# -- Node 84 --------------------------------
# Number of observations: 366
# Warning message:
# "glm.fit: algorithm did not converge"
# Parameter instability tests:
#           weekday direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0         0                     0                      0
# p.value        NA        NA                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0                   0
# p.value                      NA                     NA                  NA
#           holiday_to_right_LUX
# statistic                    0
# p.value                     NA
#
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Perform split? no
#
# -- Node 85 --------------------------------
# Number of observations: 1464
# Warning message:
# "glm.fit: algorithm did not converge"
# Parameter instability tests:
#           weekday direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0         0                     0                      0
# p.value        NA        NA                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0            13116.62
# p.value                      NA                     NA                0.00
#           holiday_to_right_LUX
# statistic             13118.77
# p.value                   0.00
#
# Best splitting variable: holiday_to_right_LUX
# Perform split? yes
# Warning message:
# "glm.fit: algorithm did not converge"Warning message:
# "glm.fit: algorithm did not converge"Warning message:
# "glm.fit: algorithm did not converge"Warning message:
# "glm.fit: algorithm did not converge"Warning message:
# "glm.fit: algorithm did not converge"Warning message:
# "glm.fit: algorithm did not converge"
# Selected split: <= 31 | > 31
#
# -- Node 86 --------------------------------
# Number of observations: 732
# Warning message:
# "glm.fit: algorithm did not converge"
# Parameter instability tests:
#           weekday direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0         0                     0                      0
# p.value        NA        NA                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0            6513.726
# p.value                      NA                     NA               0.000
#           holiday_to_right_LUX
# statistic             6510.612
# p.value                  0.000
#
# Best splitting variable: holiday_to_left_LUX
# Perform split? yes
# Warning message:
# "glm.fit: algorithm did not converge"Warning message:
# "glm.fit: algorithm did not converge"
# Selected split: <= 17 | > 17
#
# -- Node 87 --------------------------------
# Number of observations: 366
# Warning message:
# "glm.fit: algorithm did not converge"
# Parameter instability tests:
#           weekday direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0         0                     0                      0
# p.value        NA        NA                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0                   0
# p.value                      NA                     NA                  NA
#           holiday_to_right_LUX
# statistic                    0
# p.value                     NA
#
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Perform split? no
#
# -- Node 88 --------------------------------
# Number of observations: 366
# Warning message:
# "glm.fit: algorithm did not converge"
# Parameter instability tests:
#           weekday direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0         0                     0                      0
# p.value        NA        NA                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0                   0
# p.value                      NA                     NA                  NA
#           holiday_to_right_LUX
# statistic                    0
# p.value                     NA
#
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Perform split? no
#
# -- Node 89 --------------------------------
# Number of observations: 732
# Warning message:
# "glm.fit: algorithm did not converge"
# Parameter instability tests:
#           weekday direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0         0                     0                      0
# p.value        NA        NA                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0            6509.789
# p.value                      NA                     NA               0.000
#           holiday_to_right_LUX
# statistic              6509.27
# p.value                   0.00
#
# Best splitting variable: holiday_to_left_LUX
# Perform split? yes
# Warning message:
# "glm.fit: algorithm did not converge"Warning message:
# "glm.fit: algorithm did not converge"
# Selected split: <= 3 | > 3
#
# -- Node 90 --------------------------------
# Number of observations: 366
# Warning message:
# "glm.fit: algorithm did not converge"
# Parameter instability tests:
#           weekday direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0         0                     0                      0
# p.value        NA        NA                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0                   0
# p.value                      NA                     NA                  NA
#           holiday_to_right_LUX
# statistic                    0
# p.value                     NA
#
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Perform split? no
#
# -- Node 91 --------------------------------
# Number of observations: 366
# Warning message:
# "glm.fit: algorithm did not converge"
# Parameter instability tests:
#           weekday direction whichholiday_left_LUX whichholiday_right_LUX
# statistic       0         0                     0                      0
# p.value        NA        NA                    NA                     NA
#           holiday_from_left_LUX holiday_from_right_LUX holiday_to_left_LUX
# statistic                     0                      0                   0
# p.value                      NA                     NA                  NA
#           holiday_to_right_LUX
# statistic                    0
# p.value                     NA
#
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Best splitting variable: NA
# Perform split? no
#
# -- Post-pruning ---------------------------

# %%
cluster=predict(curve.model,newdata=Data,type='node')

# %%
cluster=cbind(Data,cluster)
cluster[,'cluster']=as.character(cluster[,'cluster'])
cluster=cluster[,c('weekday','direction','whichholiday_left_LUX','whichholiday_right_LUX',
'holiday_from_left_LUX','holiday_from_right_LUX','holiday_to_left_LUX','holiday_to_right_LUX','cluster')]
cluster=cluster[!duplicated(cluster),]

coefficients=coef(curve.model)
coefficients=cbind(rownames(coefficients),coefficients)
colnames(coefficients)[1]='cluster'
coefficients=merge(coefficients,cluster,by='cluster',all=TRUE)

# %%
c=200

# %%
dprio=seq(365,0,-1)

# %%
lambda=exp(as.numeric(as.character(coefficients[c,'(Intercept)']))+
(as.numeric(as.character(coefficients[c,'dprio']))*dprio)+
(as.numeric(as.character(coefficients[c,'dprio2']))*(dprio^2))+
(as.numeric(as.character(coefficients[c,'dprio3']))*(dprio^3)))

# %%
plot(dprio,cumsum(lambda),type='l')
# Out:
# plot without title

# %%
# Out:
#   [1] 1.510115e-03 3.106364e-03 4.793111e-03 6.574903e-03 8.456485e-03
#   [6] 1.044280e-02 1.253901e-02 1.475046e-02 1.708276e-02 1.954171e-02
#  [11] 2.213336e-02 2.486400e-02 2.774017e-02 3.076867e-02 3.395655e-02
#  [16] 3.731115e-02 4.084007e-02 4.455120e-02 4.845273e-02 5.255316e-02
#  [21] 5.686128e-02 6.138620e-02 6.613737e-02 7.112455e-02 7.635786e-02
#  [26] 8.184777e-02 8.760509e-02 9.364100e-02 9.996707e-02 1.065952e-01
#  [31] 1.135378e-01 1.208075e-01 1.284174e-01 1.363812e-01 1.447127e-01
#  [36] 1.534263e-01 1.625369e-01 1.720597e-01 1.820104e-01 1.924052e-01
#  [41] 2.032608e-01 2.145941e-01 2.264228e-01 2.387650e-01 2.516391e-01
#  [46] 2.650643e-01 2.790600e-01 2.936464e-01 3.088440e-01 3.246739e-01
#  [51] 3.411576e-01 3.583173e-01 3.761757e-01 3.947560e-01 4.140819e-01
#  [56] 4.341776e-01 4.550680e-01 4.767785e-01 4.993349e-01 5.227637e-01
#  [61] 5.470920e-01 5.723474e-01 5.985578e-01 6.257520e-01 6.539593e-01
#  [66] 6.832093e-01 7.135325e-01 7.449597e-01 7.775223e-01 8.112522e-01
#  [71] 8.461819e-01 8.823446e-01 9.197737e-01 9.585032e-01 9.985679e-01
#  [76] 1.040003e+00 1.082843e+00 1.127126e+00 1.172887e+00 1.220164e+00
#  [81] 1.268993e+00 1.319414e+00 1.371464e+00 1.425183e+00 1.480610e+00
#  [86] 1.537783e+00 1.596745e+00 1.657534e+00 1.720193e+00 1.784761e+00
#  [91] 1.851281e+00 1.919795e+00 1.990344e+00 2.062972e+00 2.137721e+00
#  [96] 2.214634e+00 2.293754e+00 2.375124e+00 2.458789e+00 2.544793e+00
# [101] 2.633178e+00 2.723990e+00 2.817271e+00 2.913068e+00 3.011424e+00
# [106] 3.112383e+00 3.215990e+00 3.322289e+00 3.431324e+00 3.543140e+00
# [111] 3.657782e+00 3.775292e+00 3.895715e+00 4.019095e+00 4.145476e+00
# [116] 4.274899e+00 4.407410e+00 4.543050e+00 4.681862e+00 4.823889e+00
# [121] 4.969171e+00 5.117751e+00 5.269669e+00 5.424966e+00 5.583682e+00
# [126] 5.745856e+00 5.911528e+00 6.080737e+00 6.253519e+00 6.429912e+00
# [131] 6.609953e+00 6.793678e+00 6.981122e+00 7.172319e+00 7.367304e+00
# [136] 7.566108e+00 7.768765e+00 7.975306e+00 8.185761e+00 8.400159e+00
# [141] 8.618530e+00 8.840901e+00 9.067299e+00 9.297749e+00 9.532276e+00
# [146] 9.770905e+00 1.001366e+01 1.026056e+01 1.051162e+01 1.076687e+01
# [151] 1.102632e+01 1.128999e+01 1.155790e+01 1.183007e+01 1.210649e+01
# [156] 1.238719e+01 1.267219e+01 1.296148e+01 1.325507e+01 1.355298e+01
# [161] 1.385521e+01 1.416177e+01 1.447265e+01 1.478787e+01 1.510741e+01
# [166] 1.543129e+01 1.575949e+01 1.609202e+01 1.642887e+01 1.677003e+01
# [171] 1.711551e+01 1.746528e+01 1.781934e+01 1.817767e+01 1.854027e+01
# [176] 1.890713e+01 1.927821e+01 1.965352e+01 2.003302e+01 2.041670e+01
# [181] 2.080455e+01 2.119653e+01 2.159263e+01 2.199281e+01 2.239706e+01
# [186] 2.280534e+01 2.321763e+01 2.363390e+01 2.405411e+01 2.447823e+01
# [191] 2.490624e+01 2.533809e+01 2.577375e+01 2.621318e+01 2.665634e+01
# [196] 2.710319e+01 2.755370e+01 2.800782e+01 2.846551e+01 2.892672e+01
# [201] 2.939141e+01 2.985953e+01 3.033104e+01 3.080589e+01 3.128403e+01
# [206] 3.176540e+01 3.224997e+01 3.273767e+01 3.322846e+01 3.372228e+01
# [211] 3.421908e+01 3.471879e+01 3.522138e+01 3.572678e+01 3.623493e+01
# [216] 3.674578e+01 3.725926e+01 3.777533e+01 3.829391e+01 3.881496e+01
# [221] 3.933840e+01 3.986418e+01 4.039224e+01 4.092252e+01 4.145495e+01
# [226] 4.198946e+01 4.252601e+01 4.306452e+01 4.360493e+01 4.414718e+01
# [231] 4.469120e+01 4.523693e+01 4.578430e+01 4.633325e+01 4.688372e+01
# [236] 4.743564e+01 4.798895e+01 4.854357e+01 4.909945e+01 4.965653e+01
# [241] 5.021473e+01 5.077399e+01 5.133425e+01 5.189544e+01 5.245750e+01
# [246] 5.302037e+01 5.358398e+01 5.414827e+01 5.471317e+01 5.527862e+01
# [251] 5.584456e+01 5.641093e+01 5.697766e+01 5.754470e+01 5.811197e+01
# [256] 5.867943e+01 5.924700e+01 5.981464e+01 6.038227e+01 6.094985e+01
# [261] 6.151731e+01 6.208460e+01 6.265165e+01 6.321841e+01 6.378483e+01
# [266] 6.435085e+01 6.491641e+01 6.548146e+01 6.604594e+01 6.660981e+01
# [271] 6.717300e+01 6.773548e+01 6.829718e+01 6.885805e+01 6.941806e+01
# [276] 6.997714e+01 7.053525e+01 7.109234e+01 7.164836e+01 7.220328e+01
# [281] 7.275703e+01 7.330959e+01 7.386090e+01 7.441093e+01 7.495962e+01
# [286] 7.550694e+01 7.605285e+01 7.659731e+01 7.714028e+01 7.768172e+01
# [291] 7.822160e+01 7.875987e+01 7.929650e+01 7.983146e+01 8.036472e+01
# [296] 8.089623e+01 8.142597e+01 8.195391e+01 8.248001e+01 8.300425e+01
# [301] 8.352659e+01 8.404701e+01 8.456548e+01 8.508197e+01 8.559646e+01
# [306] 8.610893e+01 8.661934e+01 8.712767e+01 8.763391e+01 8.813803e+01
# [311] 8.864001e+01 8.913982e+01 8.963746e+01 9.013289e+01 9.062611e+01
# [316] 9.111709e+01 9.160582e+01 9.209228e+01 9.257647e+01 9.305835e+01
# [321] 9.353792e+01 9.401517e+01 9.449009e+01 9.496265e+01 9.543286e+01
# [326] 9.590071e+01 9.636617e+01 9.682925e+01 9.728993e+01 9.774822e+01
# [331] 9.820409e+01 9.865755e+01 9.910859e+01 9.955721e+01 1.000034e+02
# [336] 1.004471e+02 1.008885e+02 1.013273e+02 1.017638e+02 1.021978e+02
# [341] 1.026293e+02 1.030584e+02 1.034851e+02 1.039093e+02 1.043311e+02
# [346] 1.047504e+02 1.051673e+02 1.055818e+02 1.059938e+02 1.064034e+02
# [351] 1.068106e+02 1.072154e+02 1.076177e+02 1.080177e+02 1.084152e+02
# [356] 1.088104e+02 1.092031e+02 1.095935e+02 1.099815e+02 1.103671e+02
# [361] 1.107503e+02 1.111313e+02 1.115098e+02 1.118861e+02 1.122600e+02
# [366] 1.126316e+02

# %%
coefficients=coefficients[,c(colnames(coefficients)[is.na(match(colnames(coefficients),c('(Intercept)','Dprio')))],colnames(coefficients)[!is.na(match(colnames(coefficients),c('(Intercept)','Dprio')))])]
coefficients=coefficients[,colnames(coefficients)!='cluster']

# %%
colnames(Data)
# Out:
#  [1] "calendar_date"          "weekday"                "route"
#  [4] "direction"              "dprio"                  "pax_total"
#  [7] "group_pax"              "date"                   "yday"
# [10] "whichholiday_left_LUX"  "holiday_from_left_LUX"  "holiday_from_right_LUX"
# [13] "holiday_to_left_LUX"    "holiday_to_right_LUX"   "whichholiday_right_LUX"
# [16] "whichjf_left_LUX"       "jf_left_LUX"            "jf_right_LUX"
# [19] "whichjf_right_LUX"      "dprio2"                 "dprio3"

# %%
poisson_reg <- function(route){

library(partykit)

path='/home/ubuntu/Data/'

Data=read.csv(paste0(path,'Intermediate_Output/R_Training_Pax.csv'))
Data[Data[,'NumPax']<0,'NumPax']=0

class(eq.mob <- NumPax ~ 1 + Dprio | dday + dtime)  

curve.model <- glmtree(
  eq.mob, 
  data = Data,
  family = poisson, 
  alpha = 0.01,
  bonferroni = TRUE,
  verbose = TRUE,
  prune = "BIC",
  minsize = 10,
  breakties = TRUE,
  restart = TRUE,
  maxdepth=5)

#######################################################

cluster=predict(curve.model,newdata=Data,type='node')

cluster=cbind(Data,cluster)
cluster[,'cluster']=as.character(cluster[,'cluster'])
cluster=cluster[,c('dday','dtime','cluster')]
cluster=cluster[!duplicated(cluster),]

coefficients=coef(curve.model)
coefficients=cbind(rownames(coefficients),coefficients)
colnames(coefficients)[1]='cluster'
coefficients=merge(coefficients,cluster,by='cluster',all=TRUE)
coefficients=coefficients[,c(colnames(coefficients)[is.na(match(colnames(coefficients),c('(Intercept)','Dprio')))],colnames(coefficients)[!is.na(match(colnames(coefficients),c('(Intercept)','Dprio')))])]
coefficients=coefficients[,colnames(coefficients)!='cluster']

write.csv(coefficients,paste0(path,'Intermediate_Output/Coeff_',route,'.csv'),row.names=FALSE)

}
